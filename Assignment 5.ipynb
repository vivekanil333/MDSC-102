# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("wine.data")
column_names=["class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium"," Total phenols"," Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","	Hue","OD280/OD315 of diluted wines","Proline "]
df=pd.read_csv("wine.data",names=column_names)
sns.countplot(x="Alcohol",data=df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='count'>

# %%
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#       Total phenols   Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0              2.80         3.06                  0.28             2.29
# ...

# %%
sns.scatterplot(x="Alcohol",y="Ash",data=df,hue="class") #The hue parameter is used to map a categorical variable to different colors, allowing you to visualize how data points are distributed among different categories.
# Out:
# <Axes: xlabel='Alcohol', ylabel='Ash'>

# %%
sns.scatterplot?
# Out:
# Signature:
# sns.scatterplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     size=None,
#     style=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     sizes=None,
#     size_order=None,
#     size_norm=None,
#     markers=True,
#     style_order=None,
#     legend='auto',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Draw a scatter plot with possibility of several semantic groupings.
#
# The relationship between `x` and `y` can be shown for different subsets
# of the data using the `hue`, `size`, and `style` parameters. These
# parameters control what visual semantics are used to identify the different
# subsets. It is possible to show up to three dimensions independently by
# using all three semantic types, but this style of plot can be hard to
# interpret and is often ineffective. Using redundant semantics (i.e. both
# `hue` and `style` for the same variable) can be helpful for making
# graphics more accessible.
#
# ...

# %%
sns.scatterplot(x="Alcohol",y="Malic acid",data=df,hue="class")
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
def scatterplot(df,variable,target):
    plt.figure(figsize=(20, 7))
    plt.subplot(1, 4, 3)
    sns.scatterplot(x=variable,y=target,data=df,hue="class")

# %%
scatterplot(df,"Magnesium","Alcohol")
plt.show()

# %%
scatterplot(df,"Alcohol"," Total phenols")

# %%
scatterplot(df,"Alcohol"," Flavanoids")

# %%
scatterplot(df,"Alcohol","Nonflavanoid phenols")

# %%
sns.countplot(x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#       Total phenols   Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0              2.80         3.06                  0.28             2.29
# ...

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x='class',y='Alcohol',data=df)
# Out:
# <Axes: xlabel='class', ylabel='Alcohol'>

# %%
sns.boxplot(x='class',y='Malic acid',data=df)
# Out:
# <Axes: xlabel='class', ylabel='Malic acid'>

# %%
sns.boxplot(x='class',y='Ash',data=df)
# Out:
# <Axes: xlabel='class', ylabel='Ash'>

# %%
sns.boxplot(x='class',y='Alcalinity of ash',data=df)
# Out:
# <Axes: xlabel='class', ylabel='Alcalinity of ash'>

# %%
sns.boxplot(x='class',y='Magnesium',data=df)
# Out:
# <Axes: xlabel='class', ylabel='Magnesium'>

# %%
def box_plots(df,target,variable,count):
    sns.boxplot(x=target,y=variable,data=df,hue='class')

# %%
plt.figure(figsize=(20,20))
j=1
for i in column_names[1:]:
    plt.subplot(4,4,j)
    sns.boxplot(df,x='class',y=i,hue='class')
    j+=1
  
plt.show()
# Out:
# c:\Users\Msc 1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# In the class vs alcohol
#     1 The alcohol levels are normally distributed
#     for class 2 the alcohol level is left skewed and outliers are also present
#     for class 3 the alcohol level is normally distributed
#
# For class vs malic acid
#     for class 1 the malic acid level is right skewed with outliers
#     for class 2 the malic acid level is right skewed with outliers
#     for class 3  the malic acid level is normally distributed
#
# for class vs ash
#     for class 1 the ash level is normally distributed with outliers
#     for class 2 the ash level is  right skewed with outliers
#     for class 3 the ash level is  left skewed with outliers
#
# for class vs aclanity of ash
#     for class 1 the alcanity of the ash level is right skewed
#     for class 2 the alcanity of the ash level is normally distributed
#     for class 3 right skewed
#
# for class vs magnesium
#     for the class1  magnesium level is right skewed
#     for class 2 right skewd with outliers
#     for class 3  right skewed
#
# for class vs total phenols
#     class 1 normally distributed
#     class 2 right skewed
#     class 3 left skewed with outliers
#
# for class vs flavanoids
#     class 1 normally distributed
#     class 2 normally distributed
#     class 3  right skewed with outliers
#
# for class vs non flavanoid phenols
#     class 1 right skewd
#     class2 right skewed
#     class3  rgjt skewed
#
# for class vs proanthcyanins
#     class 1  Left skewed with outliers
#     class 2  Normally skewed with outliers
#     class 3  Right skewed with outliers
#
# for class vs  Color intensity
#     class 1 - Right skewed with outliers
#     class 2 - Right skewed with outliers
#     class 3 - Right Skewed
#
# for class vs hue
#     class 1  Left Skewed
#     class 2  Right Skewed with outliers
#     class 3  Right skewed
#
# for class vs dilution
#     class 1  Right Skewed
#     class 2  Left Skewed
#     class 3  Normally distributed with outliers
#
# for class vs proline
#     class 1  Right Skewed
#     class 2  Right skewed with outliers
#     class 3  Right skewed

# %%
plt.figure(figsize=(40,80))
j = 1
k = 1
x = range(1,4)
for k in x:
        for i in column_names[1:]:

                plt.subplot(13,3,j)
                plt.title("{} of class {}" .format(i,k))
                sns.histplot(df[df["class"] == k][i], kde = True)
                j += 1

plt.show()
# Out:
# c:\Users\Msc 1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
